# %% [markdown]
# <a href="https://colab.research.google.com/github/ogiogidayo/machine-learning/blob/main/ml2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 分類/回帰 2024/10/24

# %%
from sklearn import datasets
import pandas as pd

housing = datasets.fetch_california_housing()

housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n:Number of Instances: 20640\n\n:Number of Attributes: 8 numeric, predictive attributes and the target\n\n:Attribute Information:\n    - MedInc        median income in block group\n    - HouseAge      median house age in block group\n    - AveRooms      average number of rooms per household\n    - AveBedrms     average number of bedrooms per household\n    - Population    block group population\n    - AveOccup      average number of household members\n    - Latitude      block group latitude\n    - Longitude     block group longitude\n\n:Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,000).\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nA household is a group of people residing within a home. Since the average\nnumber of rooms and bedrooms in this dataset are provided per household, these\ncolumns may take surprisingly large values for block groups with few households\nand many empty houses, such as vacation resorts.\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. rubric:: References\n\n- Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n  Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %%
print(housing.data)
# housing["data"]

print(housing.data.shape)
print(housing.target_names)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]
# (20640, 8)
# ['MedHouseVal']

# %%
# 可視化
df_housing = pd.DataFrame(housing.data, columns=housing.feature_names)

df_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df_housing_target = pd.DataFrame(housing.target, columns=housing.target_names)

df_housing_target.head()
# Out:
#    MedHouseVal
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422

# %%
df_housing["Price"] = housing.target
df_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
import matplotlib.pyplot as plt

df_housing.hist(bins=50, figsize=(13,12))

plt.show()

# %%
df_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df_housing.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
# データの加工

df_housing = df_housing[df_housing["HouseAge"] < 52]
df_housing = df_housing[df_housing["Price"] < 5]

df_housing.hist(bins=50, figsize=(13,12))

plt.show()

# %%
# 相関
df_housing.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.203107  0.317168  -0.066021    0.040688  0.025537
# HouseAge   -0.203107  1.000000 -0.181193  -0.087111   -0.280741  0.019691
# AveRooms    0.317168 -0.181193  1.000000   0.849237   -0.073623 -0.007056
# AveBedrms  -0.066021 -0.087111  0.849237   1.000000   -0.072172 -0.007865
# Population  0.040688 -0.280741 -0.073623  -0.072172    1.000000  0.065287
# AveOccup    0.025537  0.019691 -0.007056  -0.007865    0.065287  1.000000
# Latitude   -0.075389 -0.051712  0.129698   0.077281   -0.107190  0.002153
# Longitude  -0.016118 -0.034155 -0.038019   0.011199    0.091001  0.000967
# Price       0.664340  0.014121  0.115232  -0.061008    0.022542 -0.020193
#
#             Latitude  Longitude     Price
# MedInc     -0.075389  -0.016118  0.664340
# HouseAge   -0.051712  -0.034155  0.014121
# AveRooms    0.129698  -0.038019  0.115232
# AveBedrms   0.077281   0.011199 -0.061008
# Population -0.107190   0.091001  0.022542
# AveOccup    0.002153   0.000967 -0.020193
# Latitude    1.000000  -0.922738 -0.171565
# Longitude  -0.922738   1.000000 -0.022901
# Price      -0.171565  -0.022901  1.000000

# %%
df_housing.corr().style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_4c3b6_row0_col0, #T_4c3b6_row1_col1, #T_4c3b6_row2_col2, #T_4c3b6_row3_col3, #T_4c3b6_row4_col4, #T_4c3b6_row5_col5, #T_4c3b6_row6_col6, #T_4c3b6_row7_col7, #T_4c3b6_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4c3b6_row0_col1, #T_4c3b6_row1_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_4c3b6_row0_col2, #T_4c3b6_row2_col0 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_4c3b6_row0_col3, #T_4c3b6_row3_col0, #T_4c3b6_row3_col8, #T_4c3b6_row8_col3 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_4c3b6_row0_col4, #T_4c3b6_row4_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_4c3b6_row0_col5, #T_4c3b6_row5_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_4c3b6_row0_col6, #T_4c3b6_row6_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_4c3b6_row0_col7, #T_4c3b6_row5_col8, #T_4c3b6_row7_col0, #T_4c3b6_row8_col5 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_4c3b6_row0_col8, #T_4c3b6_row8_col0 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_4c3b6_row1_col2, #T_4c3b6_row2_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_4c3b6_row1_col3, #T_4c3b6_row3_col1 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_4c3b6_row1_col4, #T_4c3b6_row4_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_4c3b6_row1_col5, #T_4c3b6_row4_col8, #T_4c3b6_row5_col1, #T_4c3b6_row8_col4 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_4c3b6_row1_col6, #T_4c3b6_row6_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_4c3b6_row1_col7, #T_4c3b6_row7_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_4c3b6_row1_col8, #T_4c3b6_row3_col7, #T_4c3b6_row7_col3, #T_4c3b6_row8_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_4c3b6_row2_col3, #T_4c3b6_row3_col2 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_4c3b6_row2_col4, #T_4c3b6_row3_col4, #T_4c3b6_row4_col2, #T_4c3b6_row4_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_4c3b6_row2_col5, #T_4c3b6_row3_col5, #T_4c3b6_row5_col2, #T_4c3b6_row5_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_4c3b6_row2_col6, #T_4c3b6_row6_col2 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_4c3b6_row2_col7, #T_4c3b6_row7_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_4c3b6_row2_col8, #T_4c3b6_row8_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_4c3b6_row3_col6, #T_4c3b6_row6_col3 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_4c3b6_row4_col5, #T_4c3b6_row5_col4 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_4c3b6_row4_col6, #T_4c3b6_row6_col4 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_4c3b6_row4_col7, #T_4c3b6_row7_col4 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_4c3b6_row5_col6, #T_4c3b6_row6_col5 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_4c3b6_row5_col7, #T_4c3b6_row7_col5 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_4c3b6_row6_col7, #T_4c3b6_row7_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4c3b6_row6_col8, #T_4c3b6_row8_col6 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_4c3b6_row7_col8, #T_4c3b6_row8_col7 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c3b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c3b6_level0_col0" class="col_heading level0 col0" >MedInc</th>
#       <th id="T_4c3b6_level0_col1" class="col_heading level0 col1" >HouseAge</th>
#       <th id="T_4c3b6_level0_col2" class="col_heading level0 col2" >AveRooms</th>
#       <th id="T_4c3b6_level0_col3" class="col_heading level0 col3" >AveBedrms</th>
#       <th id="T_4c3b6_level0_col4" class="col_heading level0 col4" >Population</th>
#       <th id="T_4c3b6_level0_col5" class="col_heading level0 col5" >AveOccup</th>
#       <th id="T_4c3b6_level0_col6" class="col_heading level0 col6" >Latitude</th>
#       <th id="T_4c3b6_level0_col7" class="col_heading level0 col7" >Longitude</th>
#       <th id="T_4c3b6_level0_col8" class="col_heading level0 col8" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c3b6_level0_row0" class="row_heading level0 row0" >MedInc</th>
#       <td id="T_4c3b6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4c3b6_row0_col1" class="data row0 col1" >-0.203107</td>
#       <td id="T_4c3b6_row0_col2" class="data row0 col2" >0.317168</td>
#       <td id="T_4c3b6_row0_col3" class="data row0 col3" >-0.066021</td>
#       <td id="T_4c3b6_row0_col4" class="data row0 col4" >0.040688</td>
#       <td id="T_4c3b6_row0_col5" class="data row0 col5" >0.025537</td>
#       <td id="T_4c3b6_row0_col6" class="data row0 col6" >-0.075389</td>
#       <td id="T_4c3b6_row0_col7" class="data row0 col7" >-0.016118</td>
#       <td id="T_4c3b6_row0_col8" class="data row0 col8" >0.664340</td>
#     </tr>
#     <tr>
#       <th id="T_4c3b6_level0_row1" class="row_heading level0 row1" >HouseAge</th>
#       <td id="T_4c3b6_row1_col0" class="data row1 col0" >-0.203107</td>
#       <td id="T_4c3b6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4c3b6_row1_col2" class="data row1 col2" >-0.181193</td>
#       <td id="T_4c3b6_row1_col3" class="data row1 col3" >-0.087111</td>
#       <td id="T_4c3b6_row1_col4" class="data row1 col4" >-0.280741</td>
#       <td id="T_4c3b6_row1_col5" class="data row1 col5" >0.019691</td>
#       <td id="T_4c3b6_row1_col6" class="data row1 col6" >-0.051712</td>
#       <td id="T_4c3b6_row1_col7" class="data row1 col7" >-0.034155</td>
#       <td id="T_4c3b6_row1_col8" class="data row1 col8" >0.014121</td>
#     </tr>
#     <tr>
#       <th id="T_4c3b6_level0_row2" class="row_heading level0 row2" >AveRooms</th>
#       <td id="T_4c3b6_row2_col0" class="data row2 col0" >0.317168</td>
#       <td id="T_4c3b6_row2_col1" class="data row2 col1" >-0.181193</td>
#       <td id="T_4c3b6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4c3b6_row2_col3" class="data row2 col3" >0.849237</td>
#       <td id="T_4c3b6_row2_col4" class="data row2 col4" >-0.073623</td>
#       <td id="T_4c3b6_row2_col5" class="data row2 col5" >-0.007056</td>
#       <td id="T_4c3b6_row2_col6" class="data row2 col6" >0.129698</td>
#       <td id="T_4c3b6_row2_col7" class="data row2 col7" >-0.038019</td>
#       <td id="T_4c3b6_row2_col8" class="data row2 col8" >0.115232</td>
#     </tr>
#     <tr>
#       <th id="T_4c3b6_level0_row3" class="row_heading level0 row3" >AveBedrms</th>
#       <td id="T_4c3b6_row3_col0" class="data row3 col0" >-0.066021</td>
#       <td id="T_4c3b6_row3_col1" class="data row3 col1" >-0.087111</td>
#       <td id="T_4c3b6_row3_col2" class="data row3 col2" >0.849237</td>
#       <td id="T_4c3b6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4c3b6_row3_col4" class="data row3 col4" >-0.072172</td>
#       <td id="T_4c3b6_row3_col5" class="data row3 col5" >-0.007865</td>
#       <td id="T_4c3b6_row3_col6" class="data row3 col6" >0.077281</td>
#       <td id="T_4c3b6_row3_col7" class="data row3 col7" >0.011199</td>
#       <td id="T_4c3b6_row3_col8" class="data row3 col8" >-0.061008</td>
#     </tr>
#     <tr>
#       <th id="T_4c3b6_level0_row4" class="row_heading level0 row4" >Population</th>
#       <td id="T_4c3b6_row4_col0" class="data row4 col0" >0.040688</td>
#       <td id="T_4c3b6_row4_col1" class="data row4 col1" >-0.280741</td>
#       <td id="T_4c3b6_row4_col2" class="data row4 col2" >-0.073623</td>
#       <td id="T_4c3b6_row4_col3" class="data row4 col3" >-0.072172</td>
#       <td id="T_4c3b6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_4c3b6_row4_col5" class="data row4 col5" >0.065287</td>
#       <td id="T_4c3b6_row4_col6" class="data row4 col6" >-0.107190</td>
#       <td id="T_4c3b6_row4_col7" class="data row4 col7" >0.091001</td>
#       <td id="T_4c3b6_row4_col8" class="data row4 col8" >0.022542</td>
#     </tr>
#     <tr>
#       <th id="T_4c3b6_level0_row5" class="row_heading level0 row5" >AveOccup</th>
#       <td id="T_4c3b6_row5_col0" class="data row5 col0" >0.025537</td>
#       <td id="T_4c3b6_row5_col1" class="d

# %%
# データの正規化
def minmax_norm(df):
  return (df - df.min()) / (df.max() - df.min())

df_housing = minmax_norm(df_housing)

df_housing.hist(bins=50, figsize=(18,12))
plt.show()

# %%
# holdout
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_housing, test_size=0.2)

df_train.info()

df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14844 entries, 5922 to 19944
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      14844 non-null  float64
#  1   HouseAge    14844 non-null  float64
#  2   AveRooms    14844 non-null  float64
#  3   AveBedrms   14844 non-null  float64
#  4   Population  14844 non-null  float64
#  5   AveOccup    14844 non-null  float64
#  6   Latitude    14844 non-null  float64
#  7   Longitude   14844 non-null  float64
#  8   Price       14844 non-null  float64
# dtypes: float64(9)
# memory usage: 1.1 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 3711 entries, 19236 to 7294
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      3711 non-null   float64
#  1   HouseAge    3711 non-null   float64
#  2   AveRooms    3711 non-null   float64
#  3   AveBedrms   3711 non-null   float64
#  4   Population  3711 non-null   float64
#  5   AveOccup    3711 non-null   float64
#  6   Latitude    3711 non-null   float64
#  7   Longitude   3711 non-null   float64
#  8   Price       3711 non-null   float64
# dtypes: float64(9)
# memory usage: 289.9 KB

# %%
# KFold

from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True, random_state=1)

for train, test in kf.split(df_housing):
  print(train, test)
  df_kfold_train = df_housing.iloc[train]
  df_kfold_test = df_housing.iloc[test]
# Out:
# [    0     1     2 ... 18552 18553 18554] [    4     5     6 ... 18539 18546 18548]
# [    1     2     3 ... 18551 18553 18554] [    0     7    17 ... 18549 18550 18552]
# [    0     1     3 ... 18552 18553 18554] [    2    10    12 ... 18520 18526 18541]
# [    0     2     4 ... 18552 18553 18554] [    1     3     8 ... 18544 18545 18547]
# [    0     1     2 ... 18549 18550 18552] [    9    14    15 ... 18551 18553 18554]
